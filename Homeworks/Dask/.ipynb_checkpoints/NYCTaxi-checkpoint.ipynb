# %% [markdown]
# NYCTaxi
# ------

# %% [markdown]
# Presentado por: Yosef Guevara Salamanca

# %% [markdown]
# ### Ejercicio
#
# Taxi trips taken in 2013 released by a FOIA request.  Around 20GB CSV uncompressed.
#
# [Download link](http://www.andresmh.com/nyctaxitrips/)

# %% [markdown]
# **Try the following:**
#
# *  Use `dask.dataframe` with pandas-style queries
# *  Store in HDF5 both with and without categoricals, measure the size of the file and query times
# *  Set the index by one of the date-time columns and store in castra (also using categoricals).  Perform range queries and measure speed.  What size and complexity of query can you perform while still having an "interactive" experience?

# %% [markdown]
# ### Estableciendo cliente dask
#
# Lo primero que se realizara sera generar un cliente que contará con 4 workers y 4 hilos por worker con un máximo de memoria a utilizar de 1GB

# %%
from dask.distributed import Client
client = Client(n_workers=2, threads_per_worker=8, memory_limit='3GB')
client
# Out:
# <Client: 'tcp://127.0.0.1:53111' processes=2 threads=16, memory=5.59 GiB>

# %%
## Librerias necesarias

from glob import glob
from dask import delayed
from dask import dataframe as dd

# %% [markdown]
# ### Lectura de los datos

# %%
## Se visulizan los primeros 5 filas del dataframe

nyc = dd.read_csv('D:\\Descargas\\Taxi\\*.csv')
nyc.head()
# Out:
#                           medallion                      hack_license  \
# 0  89D227B655E5C82AECF13C3F540D4CF4  BA96DE419E711691B9445D6A6307C170
# 1  0BD7C8F5BA12B88E0B67BED28BEA73D8  9FD8F69F0804BDB5549F40E9DA1BE472
# 2  0BD7C8F5BA12B88E0B67BED28BEA73D8  9FD8F69F0804BDB5549F40E9DA1BE472
# 3  DFD2202EE08F7A8DC9A57B02ACB81FE2  51EE87E3205C985EF8431D850C786310
# 4  DFD2202EE08F7A8DC9A57B02ACB81FE2  51EE87E3205C985EF8431D850C786310
#
#   vendor_id  rate_code store_and_fwd_flag      pickup_datetime  \
# 0       CMT          1                  N  2013-01-01 15:11:48
# 1       CMT          1                  N  2013-01-06 00:18:35
# 2       CMT          1                  N  2013-01-05 18:49:41
# 3       CMT          1                  N  2013-01-07 23:54:15
# 4       CMT          1                  N  2013-01-07 23:25:03
#
#       dropoff_datetime  passenger_count  trip_time_in_secs  trip_distance  \
# 0  2013-01-01 15:18:10                4                382            1.0
# 1  2013-01-06 00:22:54                1                259            1.5
# 2  2013-01-05 18:54:23                1                282            1.1
# 3  2013-01-07 23:58:20                2                244            0.7
# 4  2013-01-07 23:34:24                1                560            2.1
#
#    pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude
# 0        -73.978165        40.757977         -73.989838         40.751171
# 1        -74.006683        40.731781         -73.994499         40.750660
# 2        -74.004707        40.737770         -74.009834         40.726002
# 3        -73.974602        40.759945         -73.984734         40.759388
# 4        -73.976250        40.748528         -74.002586         40.747868

# %% [markdown]
# ### 1. Use `dask.dataframe` with pandas-style queries

# %%
## Trips mayores a los 10 km

nyc[nyc.trip_distance > 10].head()
# Out:
#                            medallion                      hack_license  \
# 7   0B57B9633A2FECD3D3B1944AFC7471CF  CCD4367B417ED6634D986F573A552A62
# 20  D8AADA4E722C87C10E609654612630DD  8F1E4F779A4D67431C3FCFA4E70A87DC
# 28  8E189DABE265CC03FEF4BFC695B32559  906939B31C0B93768242A58A682412B8
# 38  CD9DEF073BAB75B8B36015D85FD3F777  80430F0667E3C82E63AAF4F0DC547664
# 46  8F9B593AE29F10B40EBEA0BBDEDD249F  61AF8331CB51E436B747478FC0E78B67
#
#    vendor_id  rate_code store_and_fwd_flag      pickup_datetime  \
# 7        CMT          1                  N  2013-01-07 12:39:18
# 20       CMT          2                  N  2013-01-10 23:41:51
# 28       CMT          1                  N  2013-01-01 14:02:01
# 38       CMT          1                  N  2013-01-05 03:20:28
# 46       CMT          1                  N  2013-01-07 17:38:07
#
#        dropoff_datetime  passenger_count  trip_time_in_secs  trip_distance  \
# 7   2013-01-07 13:10:56                3               1898           10.7
# 20  2013-01-11 00:09:11                1               1640           17.5
# 28  2013-01-01 14:27:39                2               1537           10.2
# 38  2013-01-05 03:43:36                4               1387           11.2
# 46  2013-01-07 17:57:46                1               1179           10.3
#
#     pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude
# 7         -73.989937        40.756775         -73.865250         40.770630
# 20        -73.783310        40.648766         -73.988914         40.748207
# 28        -73.862709        40.769142         -73.982079         40.762295
# 38        -73.991142        40.750366         -73.984436         40.618481
# 46        -73.873154        40.773998         -73.928780         40.859314

# %%
## Viajes con un numero de pasajeros igual a 3.

nyc[nyc.passenger_count == 3].head()
# Out:
#                            medallion                      hack_license  \
# 7   0B57B9633A2FECD3D3B1944AFC7471CF  CCD4367B417ED6634D986F573A552A62
# 37  764CA5AE502C0FEC9BB69DBCB6BB4ECC  26516CD746248B3495CBD99A8ABAF8B4
# 66  0CC08DE5645A7137059499EA11886805  4F2627F9FD34A9B9EFCCFC5147048345
# 77  4C005EEBAA7BF26B84B21586332488A2  351BE7D984BE17DB2FA80A748E816472
# 78  5C1E310A26EEE17AA72AFE63194DE5B5  A56B275487B0D09E6BA4C8801E0B2BE3
#
#    vendor_id  rate_code store_and_fwd_flag      pickup_datetime  \
# 7        CMT          1                  N  2013-01-07 12:39:18
# 37       CMT          1                  N  2013-01-05 20:51:53
# 66       CMT          1                  N  2013-01-07 18:45:14
# 77       CMT          1                  N  2013-01-07 21:58:43
# 78       CMT          1                  N  2013-01-01 17:11:51
#
#        dropoff_datetime  passenger_count  trip_time_in_secs  trip_distance  \
# 7   2013-01-07 13:10:56                3               1898           10.7
# 37  2013-01-05 21:02:43                3                650            3.3
# 66  2013-01-07 18:52:54                3                459            0.9
# 77  2013-01-07 22:08:42                3                598            2.0
# 78  2013-01-01 17:17:18                3                327            1.4
#
#     pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude
# 7         -73.989937        40.756775         -73.865250         40.770630
# 37        -73.993828        40.721008         -73.952400         40.723228
# 66        -73.979706        40.758427         -73.985558         40.747265
# 77        -73.987099        40.755215         -73.974457         40.755589
# 78        -73.987930        40.749542         -73.978981         40.766735

# %% [markdown]
# ### 2. Store in HDF5 both with and without categoricals, measure the size of the file and query times

# %%
## Se desactiva el cliente para permitir la escritura del archivo hdf5

client.shutdown()

# %%
## Se importa la libreria h5py

import h5py

# %%
## Se almacenan los datos como hdf5

hdf = h5py.File("D:\\Descargas\\Taxi\\Taxi.hdf5","a")
hdf
# Out:
# <HDF5 file "Taxi.hdf5" (mode r+)>

# %%
## Se reactiva el cliente

from dask.distributed import Client
client = Client(n_workers=2, threads_per_worker=8, memory_limit='3GB')
client
# Out:
# <Client: 'tcp://127.0.0.1:53146' processes=2 threads=16, memory=5.59 GiB>

# %%
## Se raliza la lectura del archivo hdf5 creado

data_hdf = dd.read_hdf("D:\\Descargas\\Taxi","\\Taxi.hdf5")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-10-9f5a7a7e09bc> in <module>
#       1 ## Se raliza la lectura del archivo hdf5 creado
#       2
# ----> 3 data_hdf = dd.read_hdf("D:\\Descargas\\Taxi","\\Taxi.hdf5")
#
# D:\Programas\miniconda3\envs\dask\lib\site-packages\dask\dataframe\io\hdf.py in read_hdf(pattern, key, start, stop, columns, chunksize, sorted_index, lock, mode)
#     410
#     411     # Build metadata
# --> 412     with pd.HDFStore(paths[0], mode=mode) as hdf:
#     413         meta_key = _expand_key(key, hdf)[0]
#     414     meta = pd.read_hdf(paths[0], meta_key, mode=mode, stop=0)
#
# D:\Programas\miniconda3\envs\dask\lib\site-packages\pandas\io\pytables.py in __init__(self, path, mode, complevel, complib, fletcher32, **kwargs)
#     570             raise ValueError("format is not a defined argument for HDFStore")
#     571
# --> 572         tables = import_optional_dependency("tables")
#     573
#     574         if complib is not None and complib not in tables.filters.all_complibs:
#
# D:\Programas\miniconda3\envs\dask\lib\site-packages\pandas\compat\_optional.py in import_optional_dependency(name, extra, errors, min_version)
#     116     except ImportError:
#     117         if errors == "raise":
# --> 118             raise ImportError(msg) from None
#     119         else:
#     120             return None
#
# ImportError: Missing optional dependency 'tables'.  Use pip or conda to install tables.

# %% [markdown]
# Nota: No fue posible leer el archivo creado menciona una libreria llamada **tables** que se encuentra obsoleta, se intenta con la nueva libreria **pytables**, pero nunca conecta al servidor por lo que fue imposible cargar el archivo como se muestra en la siguiente imagen.
#
# ![tables](./img/tables.png)

# %% [markdown]
# Se procede entonces a trabajar con el dataframe ya ejecutado

# %%
## Se verifica el tipo de variables del DataSet

nyc.dtypes
# Out:
# medallion              object
# hack_license           object
# vendor_id              object
# rate_code               int64
# store_and_fwd_flag     object
# pickup_datetime        object
# dropoff_datetime       object
# passenger_count         int64
# trip_time_in_secs       int64
# trip_distance         float64
# pickup_longitude      float64
# pickup_latitude       float64
# dropoff_longitude     float64
# dropoff_latitude      float64
# dtype: object

# %%
## Se crea una lista que contiene las varaibles no categoricas

non_categorical =['rate_code',
                 'passenger_count',
                 'trip_time_in_secs',
                 'trip_distance',
                 'pickup_longitude',
                 'pickup_latitude',
                 'dropoff_longitude',
                 'dropoff_latitude']

# %% [markdown]
# Se miden los tiempos del querry del dataset con los datos categoricos

# %%
# %%time
nyc
nyc.head()
# Out:
# Wall time: 593 ms
#                           medallion                      hack_license  \
# 0  89D227B655E5C82AECF13C3F540D4CF4  BA96DE419E711691B9445D6A6307C170
# 1  0BD7C8F5BA12B88E0B67BED28BEA73D8  9FD8F69F0804BDB5549F40E9DA1BE472
# 2  0BD7C8F5BA12B88E0B67BED28BEA73D8  9FD8F69F0804BDB5549F40E9DA1BE472
# 3  DFD2202EE08F7A8DC9A57B02ACB81FE2  51EE87E3205C985EF8431D850C786310
# 4  DFD2202EE08F7A8DC9A57B02ACB81FE2  51EE87E3205C985EF8431D850C786310
#
#   vendor_id  rate_code store_and_fwd_flag      pickup_datetime  \
# 0       CMT          1                  N  2013-01-01 15:11:48
# 1       CMT          1                  N  2013-01-06 00:18:35
# 2       CMT          1                  N  2013-01-05 18:49:41
# 3       CMT          1                  N  2013-01-07 23:54:15
# 4       CMT          1                  N  2013-01-07 23:25:03
#
#       dropoff_datetime  passenger_count  trip_time_in_secs  trip_distance  \
# 0  2013-01-01 15:18:10                4                382            1.0
# 1  2013-01-06 00:22:54                1                259            1.5
# 2  2013-01-05 18:54:23                1                282            1.1
# 3  2013-01-07 23:58:20                2                244            0.7
# 4  2013-01-07 23:34:24                1                560            2.1
#
#    pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude
# 0        -73.978165        40.757977         -73.989838         40.751171
# 1        -74.006683        40.731781         -73.994499         40.750660
# 2        -74.004707        40.737770         -74.009834         40.726002
# 3        -73.974602        40.759945         -73.984734         40.759388
# 4        -73.976250        40.748528         -74.002586         40.747868

# %% [markdown]
# Se miden los tiempos del querry del dataset sin los datos categoricos

# %%
# %%time
nyc_non = nyc[non_categorical]
nyc_non.head()
# Out:
# Wall time: 461 ms
#    rate_code  passenger_count  trip_time_in_secs  trip_distance  \
# 0          1                4                382            1.0
# 1          1                1                259            1.5
# 2          1                1                282            1.1
# 3          1                2                244            0.7
# 4          1                1                560            2.1
#
#    pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude
# 0        -73.978165        40.757977         -73.989838         40.751171
# 1        -74.006683        40.731781         -73.994499         40.750660
# 2        -74.004707        40.737770         -74.009834         40.726002
# 3        -73.974602        40.759945         -73.984734         40.759388
# 4        -73.976250        40.748528         -74.002586         40.747868

# %%
## Se crea un segundo archivo con los datos no categoricos

h5py.File("D:\\Descargas\\Taxi\\Taxi_non_cat.hdf5","a")
# Out:
# <HDF5 file "Taxi_non_cat.hdf5" (mode r+)>

# %% [markdown]
# ### 3. Set the index by one of the date-time columns and store in castra (also using categoricals). Perform range queries and measure speed. What size and complexity of query can you perform while still having an "interactive" experience?

# %% [markdown]
# Este dataset no posee columnas de fecha o tiempo como se puede observa más arriba, por lo que simplemente se procede a hacer la compración de los tiempos con algunas querys timpo pandas donde se aprecia una mayor velocidad en el dataframe qu no posee datos categoricos

# %%
# %%time

## Trips menores a los 5 km para el dataset sin datos categoricos

nyc_non[nyc_non.trip_distance < 5].head()
# Out:
# Wall time: 467 ms
#    rate_code  passenger_count  trip_time_in_secs  trip_distance  \
# 0          1                4                382            1.0
# 1          1                1                259            1.5
# 2          1                1                282            1.1
# 3          1                2                244            0.7
# 4          1                1                560            2.1
#
#    pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude
# 0        -73.978165        40.757977         -73.989838         40.751171
# 1        -74.006683        40.731781         -73.994499         40.750660
# 2        -74.004707        40.737770         -74.009834         40.726002
# 3        -73.974602        40.759945         -73.984734         40.759388
# 4        -73.976250        40.748528         -74.002586         40.747868

# %%
# %%time

## Trips menores a los 5 km para el dataset con datos categoricos

nyc[nyc.trip_distance < 5].head()
# Out:
# Wall time: 626 ms
#                           medallion                      hack_license  \
# 0  89D227B655E5C82AECF13C3F540D4CF4  BA96DE419E711691B9445D6A6307C170
# 1  0BD7C8F5BA12B88E0B67BED28BEA73D8  9FD8F69F0804BDB5549F40E9DA1BE472
# 2  0BD7C8F5BA12B88E0B67BED28BEA73D8  9FD8F69F0804BDB5549F40E9DA1BE472
# 3  DFD2202EE08F7A8DC9A57B02ACB81FE2  51EE87E3205C985EF8431D850C786310
# 4  DFD2202EE08F7A8DC9A57B02ACB81FE2  51EE87E3205C985EF8431D850C786310
#
#   vendor_id  rate_code store_and_fwd_flag      pickup_datetime  \
# 0       CMT          1                  N  2013-01-01 15:11:48
# 1       CMT          1                  N  2013-01-06 00:18:35
# 2       CMT          1                  N  2013-01-05 18:49:41
# 3       CMT          1                  N  2013-01-07 23:54:15
# 4       CMT          1                  N  2013-01-07 23:25:03
#
#       dropoff_datetime  passenger_count  trip_time_in_secs  trip_distance  \
# 0  2013-01-01 15:18:10                4                382            1.0
# 1  2013-01-06 00:22:54                1                259            1.5
# 2  2013-01-05 18:54:23                1                282            1.1
# 3  2013-01-07 23:58:20                2                244            0.7
# 4  2013-01-07 23:34:24                1                560            2.1
#
#    pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude
# 0        -73.978165        40.757977         -73.989838         40.751171
# 1        -74.006683        40.731781         -73.994499         40.750660
# 2        -74.004707        40.737770         -74.009834         40.726002
# 3        -73.974602        40.759945         -73.984734         40.759388
# 4        -73.976250        40.748528         -74.002586         40.747868
