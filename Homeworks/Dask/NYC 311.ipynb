# %% [markdown]
# # NYC 311

# %% [markdown]
# Presentado por: Yosef Guevara Salamanca

# %% [markdown]
# ## Ejercicio

# %% [markdown]
# All 311 service requests since 2010 in New York City

# %%
# Librerias necesarias

import dask.bag as db
import json
import numpy as np
import pandas as pd
import aiohttp
import requests

# %%
# Se crea un Dask bag llamado "nyc"


nyc = db.read_text('https://data.cityofnewyork.us/resource/erm2-nwe9.json').map(json.loads)
nyc
# Out:
# dask.bag<loads, npartitions=1>

# %%
# Muestra tipo de objeyo que es la varaible nyc

type(nyc)
# Out:
# dask.bag.core.Bag

# %%
df = db.read_csv('https://data.cityofnewyork.us/resource/erm2-nwe9.csv', blocksize=100)
df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-72f950422255> in <module>
# ----> 1 df = db.read_csv('https://data.cityofnewyork.us/resource/erm2-nwe9.csv', blocksize=100)
#       2 df.head()
#
# AttributeError: module 'dask.bag' has no attribute 'read_csv'

# %%
nyc.take(1)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-7-103cf4a3e395> in <module>
# ----> 1 nyc.take(1)
#
# ~/miniconda3/envs/bigdata/lib/python3.7/site-packages/dask/bag/core.py in take(self, k, npartitions, compute, warn)
#    1417
#    1418         if compute:
# -> 1419             return tuple(b.compute())
#    1420         else:
#    1421             return b
#
# ~/miniconda3/envs/bigdata/lib/python3.7/site-packages/dask/base.py in compute(self, **kwargs)
#     283         dask.base.compute
#     284         """
# --> 285         (result,) = compute(self, traverse=False, **kwargs)
#     286         return result
#     287
#
# ~/miniconda3/envs/bigdata/lib/python3.7/site-packages/dask/base.py in compute(*args, **kwargs)
#     565         postcomputes.append(x.__dask_postcompute__())
#     566
# --> 567     results = schedule(dsk, keys, **kwargs)
# ...
